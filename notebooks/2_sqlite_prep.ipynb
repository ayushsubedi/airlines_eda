# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../datasets/tableau.csv')

# %%
df
# Out:
#        airport  year  month carrier           carrier_name  \
# 0          ABE  2022      7      9E      Endeavor Air Inc.
# 1          ABE  2022      7      G4          Allegiant Air
# 2          ABE  2022      7      MQ              Envoy Air
# 3          ABE  2022      7      OH      PSA Airlines Inc.
# 4          ABE  2022      7      OO  SkyWest Airlines Inc.
# ...        ...   ...    ...     ...                    ...
# 327221     YUM  2003     10      OO  SkyWest Airlines Inc.
# 327222     YUM  2003      9      OO  SkyWest Airlines Inc.
# 327223     YUM  2003      8      OO  SkyWest Airlines Inc.
# 327224     YUM  2003      7      OO  SkyWest Airlines Inc.
# 327225     YUM  2003      6      OO  SkyWest Airlines Inc.
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         33.0
# 1       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        174.0
# ...

# %%
df_airports = df[['airport', 'airport_name', 'municipality', 'iso_region', 'iso_country', 'elevation_ft','latitude_deg', 'longitude_deg']].drop_duplicates().reset_index(drop=True)

# %%
df_airports.to_csv('airports_cleaned.csv', index=False)

# %%
df[['airport',
 'year',
 'month',
 'carrier',
 'carrier_name',
 'arr_flights',
 'arr_del15',
 'carrier_ct',
 'weather_ct',
 'nas_ct',
 'security_ct',
 'late_aircraft_ct',
 'arr_cancelled',
 'arr_diverted',
 'arr_delay',
 'carrier_delay',
 'weather_delay',
 'nas_delay',
 'security_delay',
 'late_aircraft_delay']]
# Out:
#        airport  year  month carrier           carrier_name  arr_flights  \
# 0          ABE  2022      7      9E      Endeavor Air Inc.         33.0
# 1          ABE  2022      7      G4          Allegiant Air        174.0
# 2          ABE  2022      7      MQ              Envoy Air         61.0
# 3          ABE  2022      7      OH      PSA Airlines Inc.         84.0
# 4          ABE  2022      7      OO  SkyWest Airlines Inc.         76.0
# ...        ...   ...    ...     ...                    ...          ...
# 327221     YUM  2003     10      OO  SkyWest Airlines Inc.         94.0
# 327222     YUM  2003      9      OO  SkyWest Airlines Inc.         89.0
# 327223     YUM  2003      8      OO  SkyWest Airlines Inc.         93.0
# 327224     YUM  2003      7      OO  SkyWest Airlines Inc.         92.0
# 327225     YUM  2003      6      OO  SkyWest Airlines Inc.         90.0
#
#         arr_del15  carrier_ct  weather_ct  nas_ct  security_ct  \
# ...
