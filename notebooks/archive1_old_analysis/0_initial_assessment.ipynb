# %%
import pandas as pd
import numpy as np

import sweetviz as sv

# %%
df = pd.read_csv('../datasets/Airline_Delay_Cause.csv')

# %%
df
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      7      9E     Endeavor Air Inc.     ABE
# 1       2022      7      9E     Endeavor Air Inc.     ABY
# 2       2022      7      9E     Endeavor Air Inc.     ACK
# 3       2022      7      9E     Endeavor Air Inc.     AEX
# 4       2022      7      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 321425  2003      6      DL  Delta Air Lines Inc.     SEA
# 321426  2003      6      DL  Delta Air Lines Inc.     SFO
# 321427  2003      6      DL  Delta Air Lines Inc.     SJC
# 321428  2003      6      DL  Delta Air Lines Inc.     SJU
# 321429  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         33.0
# 1                  Albany, GA: Southwest Georgia Regional         78.0
# 2                       Nantucket, MA: Nantucket Memorial        124.0
# 3                Alexandria, LA: Alexandria International         67.0
# 4             Augusta, GA: Augusta Regional at Bush Field        174.0
# ...                                                   ...          ...
# 321425          Seattle, WA: Seattle/Tacoma International        480.0
# 321426     San Francisco, CA: San Francisco International        505.0
# 321427  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 321428       San Juan, PR: Luis Munoz Marin International         95.0
# 321429   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             2.0        0.92        1.00  ...          0.0              0.00
# 1            25.0       11.80        0.72  ...          0.0              7.48
# 2            19.0        5.84        1.00  ...          0.0              5.40
# 3            10.0        1.32        1.00  ...          1.0              4.28
# 4            30.0       18.10        5.75  ...          0.0              2.55
# ...           ...         ...         ...  ...          ...               ...
# 321425       84.0       25.69        3.09  ...          0.0             21.26
# 321426      111.0       21.78        2.24  ...          0.0             13.17
# 321427       36.0        6.99        0.00  ...          0.0              2.15
# 321428       13.0        3.66        0.00  ...          0.0              1.42
# 321429      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      129.0           98.0           23.0
# 1                 0.0           0.0     1664.0          887.0           52.0
# 2                 5.0           4.0     1523.0          388.0           35.0
# 3                 0.0           1.0      657.0          103.0           82.0
# 4                 1.0           0.0     2462.0         1686.0          310.0
# ...               ...           ...        ...            ...            ...
# 321425            0.0           0.0     3744.0          978.0          164.0
# 321426            3.0           0.0     4284.0         1376.0          138.0
# 321427            0.0           0.0      896.0          205.0            0.0
# 321428            0.0           0.0      367.0          120.0            0.0
# 321429            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             8.0             0.0                  0.0
# 1           224.0             0.0                501.0
# 2           511.0             0.0                589.0
# 3            93.0            25.0                354.0
# 4           139.0             0.0                327.0
# ...           ...             ...                  ...
# 321425     1023.0             0.0               1579.0
# 321426     2132.0             0.0                638.0
# 321427      607.0             0.0                 84.0
# 321428      210.0             0.0                 37.0
# 321429     5686.0            28.0               5449.0
#
# [321430 rows x 21 columns]

# %%
df.shape
# Out:
# (321430, 21)

# %% [markdown]
# # Data dictionary

# %% [markdown]
# | **Column **         | **Description**                                                                                         |
# |---------------------|---------------------------------------------------------------------------------------------------------|
# | year                | Year data collected                                                                                     |
# | month               | Numeric representation of the month                                                                     |
# | carrier             | Carrier's IATA Code                                                                                     |
# | carrier_name        | Carrier Name.                                                                                           |
# | airport             | Airport code.                                                                                           |
# | airport_name        | Name of airport.                                                                                        |
# | arr_flights         | Number of flights arriving at airport                                                                   |
# | arr_del15           | Number of flights more than 15 minutes late                                                             |
# | carrier_ct          | Number of flights delayed due to air carrier. (e.g. no crew)                                            |
# | weather_ct          | Number of flights due to weather.                                                                       |
# | nas_ct              | Number of flights delayed due to National Aviation System (e.g. heavy air traffic).                     |
# | security_ct         | Number of flights canceled due to a security breach.                                                    |
# | late_aircraft_ct    | Number of flights delayed as a result of another flight on the same aircraft delayed                    |
# | arr_cancelled       | Number of cancelled flights                                                                             |
# | arr_diverted        | Number of flights that were diverted                                                                    |
# | arr_delay           | Total time (minutes) of delayed flight.                                                                 |
# | carrier_delay       | Total time (minutes) of delay due to air carrier                                                        |
# | weather_delay       | Total time (minutes) of delay due to inclement weather.                                                 |
# | nas_delay           | Total time (minutes) of delay due to National Aviation System.                                          |
# | security_delay      | Total time (minutes) of delay as a result of a security issue .                                         |
# | late_aircraft_delay | Total time (minutes) of delay flights as a result of a previous flight on the same airplane being late. |

# %%
eda_report_sweetviz = sv.analyze(df)
# Out:
#                                              |      | [  0%]   00:00 -> (? left)

# %%
eda_report_sweetviz.show_html(filepath='../profiler_reports/eda_report_sweetviz.html', 
            open_browser=True, 
            layout='widescreen', 
            scale=None)
# Out:
# Report ../profiler_reports/eda_report_sweetviz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
