# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/Airline_Delay_Cause.csv')

# %%
df_airports = pd.read_csv('../datasets/airports.csv')

# %%
df_airports
# Out:
#     IATA                              AIRPORT                            CITY  \
# 0    ABQ            Albuquerque International                     Albuquerque
# 1    ANC  Ted Stevens Anchorage International                       Anchorage
# 2    ATL    William B Hartsfield-Atlanta Intl                         Atlanta
# 3    AUS       Austin-Bergstrom International                          Austin
# 4    BDL                Bradley International                   Windsor Locks
# ..   ...                                  ...                             ...
# 336  WRG                             Wrangell                        Wrangell
# 337  WYS                          Yellowstone                West Yellowstone
# 338  XNA          Northwest Arkansas Regional  Fayetteville Springdale Rogers
# 339  YAK                              Yakutat                         Yakutat
# 340  YUM         Yuma MCAS-Yuma International                            Yuma
#
# ...

# %%
df = df.set_index('airport').join(df_airports.set_index('IATA'))

# %%
df
# Out:
#      year  month carrier           carrier_name  \
# ABE  2022      7      9E      Endeavor Air Inc.
# ABE  2022      7      G4          Allegiant Air
# ABE  2022      7      MQ              Envoy Air
# ABE  2022      7      OH      PSA Airlines Inc.
# ABE  2022      7      OO  SkyWest Airlines Inc.
# ..    ...    ...     ...                    ...
# YUM  2003     10      OO  SkyWest Airlines Inc.
# YUM  2003      9      OO  SkyWest Airlines Inc.
# YUM  2003      8      OO  SkyWest Airlines Inc.
# YUM  2003      7      OO  SkyWest Airlines Inc.
# YUM  2003      6      OO  SkyWest Airlines Inc.
#
#                                           airport_name  arr_flights  \
# ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         33.0
# ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        174.0
# ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         61.0
# ABE  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         84.0
# ...

# %%
list(df)
# Out:
# ['year',
#  'month',
#  'carrier',
#  'carrier_name',
#  'airport_name',
#  'arr_flights',
#  'arr_del15',
#  'carrier_ct',
#  'weather_ct',
#  'nas_ct',
#  'security_ct',
#  'late_aircraft_ct',
#  'arr_cancelled',
#  'arr_diverted',
#  'arr_delay',
#  'carrier_delay',
#  'weather_delay',
#  'nas_delay',
#  'security_delay',
#  'late_aircraft_delay',
#  'AIRPORT',
#  'CITY',
#  'STATE',
#  'COUNTRY',
#  'LATITUDE',
#  'LONGITUDE']

# %%
df = df[['year',
 'month',
 'carrier',
 'carrier_name',
 'airport_name',
 'arr_flights',
 'arr_del15',
 'carrier_ct',
 'weather_ct',
 'nas_ct',
 'security_ct',
 'late_aircraft_ct',
 'arr_cancelled',
 'arr_diverted',
 'arr_delay',
 'carrier_delay',
 'weather_delay',
 'nas_delay',
 'security_delay',
 'late_aircraft_delay',
 'CITY',
 'STATE',
 'COUNTRY',
 'LATITUDE',
 'LONGITUDE']].reset_index().rename(columns={'index': 'IATA'})

# %%
df.to_csv('../datasets/tableau.csv', index=False)
