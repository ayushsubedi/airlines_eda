# %%
import pandas as pd

# %%
df = pd.read_csv('../datasets/Airline_Delay_Cause.csv')

# %%
df_airports = pd.read_csv('../datasets/airports.csv')

# %%
df_airports
# Out:
#     IATA                              AIRPORT                            CITY  \
# 0    ABQ            Albuquerque International                     Albuquerque
# 1    ANC  Ted Stevens Anchorage International                       Anchorage
# 2    ATL    William B Hartsfield-Atlanta Intl                         Atlanta
# 3    AUS       Austin-Bergstrom International                          Austin
# 4    BDL                Bradley International                   Windsor Locks
# ..   ...                                  ...                             ...
# 336  WRG                             Wrangell                        Wrangell
# 337  WYS                          Yellowstone                West Yellowstone
# 338  XNA          Northwest Arkansas Regional  Fayetteville Springdale Rogers
# 339  YAK                              Yakutat                         Yakutat
# 340  YUM         Yuma MCAS-Yuma International                            Yuma
#
#     STATE COUNTRY   LATITUDE   LONGITUDE
# 0      NM     USA  35.040222 -106.609194
# 1      AK     USA  61.174320 -149.996186
# 2      GA     USA  33.640444  -84.426944
# 3      TX     USA  30.194533  -97.669872
# 4      CT     USA  41.938874  -72.683228
# ..    ...     ...        ...         ...
# 336    AK     USA  56.484326 -132.369824
# 337    MT     USA  44.688399 -111.117638
# 338    AR     USA  36.281869  -94.306811
# 339    AK     USA  59.503361 -139.660226
# 340    AZ     USA  32.656583 -114.605972
#
# [341 rows x 7 columns]

# %%
df = df.set_index('airport').join(df_airports.set_index('IATA')).reset_index(drop=True)

# %%
df
# Out:
#         year  month carrier           carrier_name  \
# 0       2022      7      9E      Endeavor Air Inc.
# 1       2022      7      G4          Allegiant Air
# 2       2022      7      MQ              Envoy Air
# 3       2022      7      OH      PSA Airlines Inc.
# 4       2022      7      OO  SkyWest Airlines Inc.
# ...      ...    ...     ...                    ...
# 321425  2003     10      OO  SkyWest Airlines Inc.
# 321426  2003      9      OO  SkyWest Airlines Inc.
# 321427  2003      8      OO  SkyWest Airlines Inc.
# 321428  2003      7      OO  SkyWest Airlines Inc.
# 321429  2003      6      OO  SkyWest Airlines Inc.
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         33.0
# 1       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        174.0
# 2       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         61.0
# 3       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         84.0
# 4       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         76.0
# ...                                                   ...          ...
# 321425             Yuma, AZ: Yuma MCAS/Yuma International         94.0
# 321426             Yuma, AZ: Yuma MCAS/Yuma International         89.0
# 321427             Yuma, AZ: Yuma MCAS/Yuma International         93.0
# 321428             Yuma, AZ: Yuma MCAS/Yuma International         92.0
# 321429             Yuma, AZ: Yuma MCAS/Yuma International         90.0
#
#         arr_del15  carrier_ct  weather_ct  nas_ct  ...  weather_delay  \
# 0             2.0        0.92        1.00    0.08  ...           23.0
# 1            68.0       12.44        5.98   11.54  ...          556.0
# 2             7.0        1.34        0.00    1.12  ...            0.0
# 3            20.0        5.66        1.11    7.62  ...           99.0
# 4            28.0       22.00        6.00    0.00  ...          866.0
# ...           ...         ...         ...     ...  ...            ...
# 321425        6.0        1.00        1.00    2.00  ...           23.0
# 321426        8.0        5.00        1.00    0.00  ...           18.0
# 321427        4.0        4.00        0.00    0.00  ...            0.0
# 321428        4.0        3.00        0.00    1.00  ...            0.0
# 321429        4.0        0.00        0.00    0.00  ...            0.0
#
#         nas_delay  security_delay  late_aircraft_delay  \
# 0             8.0             0.0                  0.0
# 1           731.0             0.0               2614.0
# 2            75.0             0.0                327.0
# 3           338.0             0.0                360.0
# 4             0.0             0.0                  0.0
# ...           ...             ...                  ...
# 321425       92.0             0.0                 61.0
# 321426        0.0             0.0                134.0
# 321427        0.0             0.0                  0.0
# 321428       17.0             0.0                  0.0
# 321429        0.0            53.0                 69.0
#
#                              AIRPORT       CITY  STATE  COUNTRY   LATITUDE  \
# 0        Lehigh Valley International  Allentown     PA      USA  40.652363
# 1        Lehigh Valley International  Allentown     PA      USA  40.652363
# 2        Lehigh Valley International  Allentown     PA      USA  40.652363
# 3        Lehigh Valley International  Allentown     PA      USA  40.652363
# 4        Lehigh Valley International  Allentown     PA      USA  40.652363
# ...                              ...        ...    ...      ...        ...
# 321425  Yuma MCAS-Yuma International       Yuma     AZ      USA  32.656583
# 321426  Yuma MCAS-Yuma International       Yuma     AZ      USA  32.656583
# 321427  Yuma MCAS-Yuma International       Yuma     AZ      USA  32.656583
# 321428  Yuma MCAS-Yuma International       Yuma     AZ      USA  32.656583
# 321429  Yuma MCAS-Yuma International       Yuma     AZ      USA  32.656583
#
#          LONGITUDE
# 0       -75.440402
# 1       -75.440402
# 2       -75.440402
# 3       -75.440402
# 4       -75.440402
# ...            ...
# 321425 -114.605972
# 321426 -114.605972
# 321427 -114.605972
# 321428 -114.605972
# 321429 -114.605972
#
# [321430 rows x 26 columns]

# %%
df.to_csv('../datasets/tableau.csv', index=False)
